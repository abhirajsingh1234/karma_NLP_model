# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv
import ast
import pandas
load_dotenv()
# Out:
# True

# %%
data=pandas.read_csv('Content_Storage_df.csv')
content_storage=pandas.DataFrame(data)

# %%
content_storage.loc[1234,:]
# Out:
# Unnamed: 0                                                       1234
# chapter_id                                                        246
# chapter_name                                              chapter 246
# verse_id                                                            4
# verse_text          said :the rishis such as shaunaka, etc, having...
# embedding_vector    [-0.06436804682016373, 0.036371856927871704, -...
# summary             The puranam should be constantly re cited, and...
# Name: 1234, dtype: object

# %%
# genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# available_models = genai.list_models()
# for model in available_models:
#     print(model.name)

# %%
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# genai.configure(api_key="your geminig api key")

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8190,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash-latest",
  generation_config=generation_config,
  # system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\nOutput the results in Python dictionary format as follows:\npython\nCopy\nEdit\n{\n    'chapter_id': chapter_id,\n    'verse_id': verse_id,\n    'question': question,\n    'answer': answer,\n    'verse_text': verse_text\n}\nReturn a list of 5 such dictionaries, one for each question-answer pair.",
  system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\n\n**IMPORTANT: Output the results as a valid Python list of dictionaries. Each dictionary MUST have the keys 'chapter_id', 'verse_id', 'question', 'answer', and 'verse_text'. The entire output MUST be enclosed in square brackets to represent a list. Each dictionary MUST be enclosed in curly braces. Ensure that the keys and values are enclosed in double quotes.**\n\n**Example Output Format:**\n```python\n[\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"What is the main topic?\",\n    \"answer\": \"The main topic is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Who is the author?\",\n    \"answer\": \"The author is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Why did this happen?\",\n    \"answer\": \"Because...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n    {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"When did this happen?\",\n    \"answer\": \"In 1945...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Where did this happen?\",\n    \"answer\": \"In Germany...\",\n    \"verse_text\": \"The text of the verse.\"\n  }\n]",

)

model2= genai.GenerativeModel(
  model_name="gemini-1.5-flash-8b",
  generation_config=generation_config,
  # system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\nOutput the results in Python dictionary format as follows:\npython\nCopy\nEdit\n{\n    'chapter_id': chapter_id,\n    'verse_id': verse_id,\n    'question': question,\n    'answer': answer,\n    'verse_text': verse_text\n}\nReturn a list of 5 such dictionaries, one for each question-answer pair.",
  system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\n\n**IMPORTANT: Output the results as a valid Python list of dictionaries. Each dictionary MUST have the keys 'chapter_id', 'verse_id', 'question', 'answer', and 'verse_text'. The entire output MUST be enclosed in square brackets to represent a list. Each dictionary MUST be enclosed in curly braces. Ensure that the keys and values are enclosed in double quotes.**\n\n**Example Output Format:**\n```python\n[\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"What is the main topic?\",\n    \"answer\": \"The main topic is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Who is the author?\",\n    \"answer\": \"The author is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Why did this happen?\",\n    \"answer\": \"Because...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n    {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"When did this happen?\",\n    \"answer\": \"In 1945...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Where did this happen?\",\n    \"answer\": \"In Germany...\",\n    \"verse_text\": \"The text of the verse.\"\n  }\n]",

)

model3= genai.GenerativeModel(
  model_name="gemini-1.5-flash-latest",
  generation_config=generation_config,
  # system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\nOutput the results in Python dictionary format as follows:\npython\nCopy\nEdit\n{\n    'chapter_id': chapter_id,\n    'verse_id': verse_id,\n    'question': question,\n    'answer': answer,\n    'verse_text': verse_text\n}\nReturn a list of 5 such dictionaries, one for each question-answer pair.",
  system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\n\n**IMPORTANT: Output the results as a valid Python list of dictionaries. Each dictionary MUST have the keys 'chapter_id', 'verse_id', 'question', 'answer', and 'verse_text'. The entire output MUST be enclosed in square brackets to represent a list. Each dictionary MUST be enclosed in curly braces. Ensure that the keys and values are enclosed in double quotes.**\n\n**Example Output Format:**\n```python\n[\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"What is the main topic?\",\n    \"answer\": \"The main topic is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Who is the author?\",\n    \"answer\": \"The author is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Why did this happen?\",\n    \"answer\": \"Because...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n    {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"When did this happen?\",\n    \"answer\": \"In 1945...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Where did this happen?\",\n    \"answer\": \"In Germany...\",\n    \"verse_text\": \"The text of the verse.\"\n  }\n]",

)

model4= genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\nOutput the results in Python dictionary format as follows:\npython\nCopy\nEdit\n{\n    'chapter_id': chapter_id,\n    'verse_id': verse_id,\n    'question': question,\n    'answer': answer,\n    'verse_text': verse_text\n}\nReturn a list of 5 such dictionaries, one for each question-answer pair.",
  system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\n\n**IMPORTANT: Output the results as a valid Python list of dictionaries. Each dictionary MUST have the keys 'chapter_id', 'verse_id', 'question', 'answer', and 'verse_text'. The entire output MUST be enclosed in square brackets to represent a list. Each dictionary MUST be enclosed in curly braces. Ensure that the keys and values are enclosed in double quotes.**\n\n**Example Output Format:**\n```python\n[\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"What is the main topic?\",\n    \"answer\": \"The main topic is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Who is the author?\",\n    \"answer\": \"The author is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Why did this happen?\",\n    \"answer\": \"Because...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n    {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"When did this happen?\",\n    \"answer\": \"In 1945...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Where did this happen?\",\n    \"answer\": \"In Germany...\",\n    \"verse_text\": \"The text of the verse.\"\n  }\n]",

)
history=[]

qa_pairs=[]
errored_chapter_verse=[]


# print('1')

for index,row in content_storage.iterrows():
    if row['chapter_id']>=213:
        try:
    
            # print('2')
            
            user_input = f"chapter_id={row['chapter_id']}, verse_id={row['verse_id']}, verse_text='{row['verse_text']}'"
    
            # print('3')
        
            chat_session = model.start_chat(
                history=history
            )
            chat_session2 = model2.start_chat(
                history=history
            )
            chat_session3 = model3.start_chat(
                history=history
            )
            chat_session4 = model4.start_chat(
                history=history
            )
    
            # print('4')
            
            response = chat_session.send_message(user_input)
            response2 = chat_session2.send_message(user_input)
            response3 = chat_session3.send_message(user_input)
            response4 = chat_session4.send_message(user_input)
    
            # print('5')
            
            model_response=response.text
            model_response2=response2.text
            model_response3=response3.text
            model_response4=response4.text
            
    
            # print('6 \n\n',model_response)
    
            # print('6 \n\n',model_response2)
            # print('6 \n\n',model_response3)
            # print('6 \n\n',model_response4)
            
            # history.append({'role':'user','parts':[user_input]})
            # history.append({'role':'model','parts':[model_response]})
            # print(model_response)
            try:
                cleaned_response=model_response.strip().strip("```").replace("python", "").rstrip("```")
            except:
                cleaned_response=model_response.strip().strip("```").replace("json", "").rstrip("```")  
            try:
                cleaned_response2=model_response.strip().strip("```").replace("python", "").rstrip("```")
            except:
                cleaned_response2=model_response.strip().strip("```").replace("json", "").rstrip("```")
            try:
                cleaned_response3=model_response.strip().strip("```").replace("python", "").rstrip("```")
            except:
                cleaned_response3=model_response.strip().strip("```").replace("json", "").rstrip("```")
            try:
                cleaned_response4=model_response.strip().strip("```").replace("python", "").rstrip("```")
            except:
                cleaned_response4=model_response.strip().strip("```").replace("json", "").rstrip("```")
            
            
            # print('7 \n\n',cleaned_response2)
            
            list_response=ast.literal_eval(cleaned_response)
            # print('8 \n\n',list_response)
            list_response2=ast.literal_eval(cleaned_response2)
            # print('9 \n\n',list_response2)
            list_response3=ast.literal_eval(cleaned_response3)
            # print('10 \n\n',list_response3)
            list_response4=ast.literal_eval(cleaned_response4)
    
            # print('11 \n\n',list_response4)
            
            for i in list_response:
              qa_pairs.append(i)
              # print(i)
              
            for i in list_response2:
              qa_pairs.append(i)
              # print(i)
                
            for i in list_response3:
              qa_pairs.append(i)
              # print(i)
            
            for i in list_response4:
              qa_pairs.append(i)
              # print(i)
    
            if row['chapter_id']==246 and row['verse_id']==4:
                df=pandas.DataFrame(qa_pairs)
                df.to_csv(f"qa_pairs_213_to_246.csv")
                print(f"\n\n\ncsv successfully created at {row['chapter_id']}\n\n\n")
                
            print(f"success at chapter {row['chapter_id']} verse {row['verse_id']}")
              
        except Exception as e:
            print(e)
            errored_chapter_verse.append(f"chapter_id - {row['chapter_id']}, verse_id - {row['verse_id']}")
            print(f"error at chapter {row['chapter_id']} verse {row['verse_id']}")
            pass
# Out:
# success at chapter 213 verse 0
# success at chapter 213 verse 1
# success at chapter 213 verse 2
# success at chapter 213 verse 3
# success at chapter 213 verse 4
# success at chapter 214 verse 0
# success at chapter 214 verse 1
# success at chapter 214 verse 2
# success at chapter 214 verse 3
# success at chapter 214 verse 4
# success at chapter 215 verse 0
# success at chapter 215 verse 1
# success at chapter 215 verse 2
# success at chapter 215 verse 3
# success at chapter 215 verse 4
# success at chapter 216 verse 0
# success at chapter 216 verse 1
# success at chapter 216 verse 2
# success at chapter 216 verse 3
# success at chapter 216 verse 4
# success at chapter 217 verse 0
# success at chapter 217 verse 1
# success at chapter 217 verse 2
# success at chapter 217 verse 3
# success at chapter 217 verse 4
# success at chapter 218 verse 0
# success at chapter 218 verse 1
# success at chapter 218 verse 2
# success at chapter 218 verse 3
# success at chapter 218 verse 4
# ...

# %%
success at chapter 86 verse 1

# %%
df=pandas.DataFrame(qa_pairs)
df.to_csv(f"qa_pairs_86_213.csv")

# %%
# import re
# genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# # genai.configure(api_key="your geminig api key")

# # Create the model
# generation_config = {
#   "temperature": 1,
#   "top_p": 0.95,
#   "top_k": 40,
#   "max_output_tokens": 8190,
#   "response_mime_type": "text/plain",
# }

# model = genai.GenerativeModel(
#   model_name="gemini-1.5-flash-latest",
#   generation_config=generation_config,
#   # system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\nOutput the results in Python dictionary format as follows:\npython\nCopy\nEdit\n{\n    'chapter_id': chapter_id,\n    'verse_id': verse_id,\n    'question': question,\n    'answer': answer,\n    'verse_text': verse_text\n}\nReturn a list of 5 such dictionaries, one for each question-answer pair.",
#   system_instruction="You are an AI assistant skilled at generating high-quality question-answer pairs. Given an input containing chapter_id, verse_id, and verse_text, your task is to generate 5 diverse question-answer pairs based on the verse_text.\n\nGuidelines:\nEach answer must be directly found within the verse_text.\nEnsure that the questions vary in type, including who, what, when, where, why, and how formats.\nKeep the question-answer pairs relevant to the verse_text while maintaining coherence.\n\n**IMPORTANT: Output the results as a valid Python list of dictionaries. Each dictionary MUST have the keys 'chapter_id', 'verse_id', 'question', 'answer', and 'verse_text'. The entire output MUST be enclosed in square brackets to represent a list. Each dictionary MUST be enclosed in curly braces. Ensure that the keys and values are enclosed in double quotes.**\n\n**Example Output Format:**\n```python\n[\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"What is the main topic?\",\n    \"answer\": \"The main topic is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Who is the author?\",\n    \"answer\": \"The author is...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Why did this happen?\",\n    \"answer\": \"Because...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n    {\n   \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"When did this happen?\",\n    \"answer\": \"In 1945...\",\n    \"verse_text\": \"The text of the verse.\"\n  },\n  {\n    \"chapter_id\": 1,\n    \"verse_id\": 1,\n    \"question\": \"Where did this happen?\",\n    \"answer\": \"In Germany...\",\n    \"verse_text\": \"The text of the verse.\"\n  }\n]",

# )

# user_input = "chapter_id=0, verse_id=0, verse_text='i preface a few preliminary remarks on the history, scope and contents of the garuda puranam may be necessary the garuda puranam l may be safely described as a sister work to the agni puranam each of them treats of par vidy and apara vidya, secular knowledge and metaphysical truths, and par takes more of the nature of a catechism of the then prevailing brahmanism, or of what a brahmana was required to know at the tune, than of the puranm proper, at least if we may be admitted to look upon the rmyana or the mahbhratam as the model of that class of literature superficially conforming to the rules of pancha sandhis, etc, the garuda puranam, like its sister work, reflects but the knowledge of the brahmanical world at the time, and had its uses then as it has even now without doing violence to the antiquarian instinct, we must say that it is quite futile to attempt to lay down the precise date of the composition of the garuda puranam its name occurs in the halyudhas brahmans sarvasvam chakrpani dntta has quoted many a recipe from it, and the vishnu dharmottartun, according to several eminent authorities, orginally formed a portion of the garuda puranam all these factors emphatically demonstrate the fact that, the garuda puranam was in existence even before the tenth century of the christian era on the contrary, we have reasons to believe that, hosts of puranas and upapuranas were composed in the age of brah manic renascence, which immediately followed the overthrow of buddhism in india the garuda puranm, like the agni, shiva, padma, and the like puranas, were the exponents of the victorious brahmanism, which, being inevitably divided into achisms, tried to invest the tutelary deity of each sect with the attributes of supreme divinity or brahma, and to equip its , members with a complete code of rituals, law and other neces sary informations regarding the incidents of every day life, subservient to, and in conformity with, the vedas and the vedic literature thus each schism or faction, or more correctly, each puranam, the scripture of each sect of special, tutelary divinities, became a new school of law, medicine and metaphysics, etc, reinstating the old errors of the vedic literature as if to ignore the many advanced truths and principles of the later day buddhistic science, and to confirm the victory of brahmanism even in error and fallacy the description of the incidents of the life of buddha, however meagre and incidental it might be, and the occurrence of the name of sushruta in the medical portion of the garuda puranam leaves not the slightest doubt that its author was intimately acquainted with the buddhistic literature of the age, both medical and metaphysical it is a settled fact of history that the sushruta samhita, at least the recension of the sashruta samhita by the buddhist nagarjuna, was written in the second century bef'"

# chat_session = model.start_chat(
#             history=history
#         )

# response = chat_session.send_message(user_input)

# model_response=response.text
# print(model_response,'\n\n')

# cleaned_response=model_response.strip().strip("```").replace("python", "").rstrip("```")


# print(cleaned_response,'\n\n')

# list_response=ast.literal_eval(cleaned_response)

# for i in list_response:
#     print(i)

# %%
data1=pandas.read_csv('qa_pairs_to_86.csv')
data2=pandas.read_csv('qa_pairs_86_213.csv')
data3=pandas.read_csv('qa_pairs_213_to_246.csv')

df1=pandas.DataFrame(data1)
df2=pandas.DataFrame(data2)
df3=pandas.DataFrame(data3)

# %%
df12=pandas.concat([df1,df2],ignore_index=True, sort=False)

# %%
df123=pandas.concat([df12,df3],ignore_index=True,sort=False)

# %%
df123.head(5)
# Out:
#    Unnamed: 0  chapter_id  verse_id  \
# 0           0           0         0
# 1           1           0         0
# 2           2           0         0
# 3           3           0         0
# 4           4           0         0
#
#                                             question  \
# 0  What is the Garuda Puranam described as in rel...
# 1  What topics do the Garuda Puranam and Agni Pur...
# 2  Before what century is the Garuda Puranam conf...
# 3  What is mentioned as originally forming a port...
# 4   Who quoted many recipes from the Garuda Puranam?
#
#                                               answer  \
# 0                                      a sister work
# 1  par vidy and apara vidya, secular knowledge an...
# 2                 tenth century of the christian era
# 3                           the vishnu dharmottartun
# 4                                    chakrpani dntta
#
#                                           verse_text
# ...

# %%
df123.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df123.to_csv('qa_pairs.csv')
